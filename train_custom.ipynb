# %%
# !nvidia-smi
# Out:
# Sun Aug 23 02:50:05 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc --version

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

# %%
# %cd /content
# !unzip /content/gdrive/'My Drive'/Final-project-YOLOv3/darknet.zip
# %cd /content/darknet

# %%
# !sudo apt install dos2unix

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/valid.txt
# !dos2unix ./data/yolo.data
# !dos2unix ./data/yolo.names
# !dos2unix ./cfg/yolov3_custom.cfg

# %%
# %cd /content/darknet
# !make clean
# !make
# !chmod +x ./darknet

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/gdrive/'My Drive'/Final-project-YOLOv3/backup /content/darknet

# %%
# !ls -l backup

# %%
# %cd /content/darknet

# For training from beginning
# !./darknet detector train data/yolo.data cfg/yolov3_custom.cfg darknet53.conv.74

# For training from previous weights
# !./darknet detector train data/yolo.data cfg/yolov3_custom.cfg backup/yolov3_custom_1000.weights
